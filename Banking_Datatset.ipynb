# %% [markdown]
# **<h1><center>Banking Dataset:</center></h1>**

# %% [markdown]
# **<h2><center>Group 9:</center></h2>**
# <h3><center>Shashvat Sachdeva</center></h3>
# <h3><center>Archit Raju Asutkar</center></h3>
# <h3><center>Tushar Rajendra Shinde</center></h3>
# <h3><center>Weeramundage Ishani Madushika Piyathilake</center></h3>
# <h3><center>Dhrumi Tapas Patel</center></h3>

# %% [markdown]
# **Loading libraries as follows:**

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import plotly.express as px
import altair as alt 
# %matplotlib inline

# %% [markdown]
# **Loading Dataset as follows:**

# %%
data=pd.read_csv("/content/bank-direct-marketing-campaigns.csv")

# %%
data.head(20)
# Out:
#     age          job   marital  ... euribor3m nr.employed   y
# 0    56    housemaid   married  ...     4.857      5191.0  no
# 1    57     services   married  ...     4.857      5191.0  no
# 2    37     services   married  ...     4.857      5191.0  no
# 3    40       admin.   married  ...     4.857      5191.0  no
# 4    56     services   married  ...     4.857      5191.0  no
# 5    45     services   married  ...     4.857      5191.0  no
# 6    59       admin.   married  ...     4.857      5191.0  no
# 7    41  blue-collar   married  ...     4.857      5191.0  no
# 8    24   technician    single  ...     4.857      5191.0  no
# 9    25     services    single  ...     4.857      5191.0  no
# 10   41  blue-collar   married  ...     4.857      5191.0  no
# 11   25     services    single  ...     4.857      5191.0  no
# 12   29  blue-collar    single  ...     4.857      5191.0  no
# 13   57    housemaid  divorced  ...     4.857      5191.0  no
# ...

# %% [markdown]
# **Below code illustrates information about the datatset:**

# %%
data.info
# Out:
# <bound method DataFrame.info of        age          job  marital  ... euribor3m nr.employed    y
# 0       56    housemaid  married  ...     4.857      5191.0   no
# 1       57     services  married  ...     4.857      5191.0   no
# 2       37     services  married  ...     4.857      5191.0   no
# 3       40       admin.  married  ...     4.857      5191.0   no
# 4       56     services  married  ...     4.857      5191.0   no
# ...    ...          ...      ...  ...       ...         ...  ...
# 41183   73      retired  married  ...     1.028      4963.6  yes
# 41184   46  blue-collar  married  ...     1.028      4963.6   no
# 41185   56      retired  married  ...     1.028      4963.6   no
# 41186   44   technician  married  ...     1.028      4963.6  yes
# 41187   74      retired  married  ...     1.028      4963.6   no
#
# [41188 rows x 20 columns]>

# %% [markdown]
# **Variables Description:**
#
# 1.   **age** (numeric)
# 2.   **job** : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
# 3.   **marital** : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
# 4.  **education** (categorical: "unknown","secondary","primary","tertiary")
# 5.  **default**: has credit in default? (binary: "yes","no")
# 6.  **balance**: average yearly balance, in euros (numeric)
# 7.  **housing**: has housing loan? (binary: "yes","no")
# 8.  **loan**: has personal loan? (binary: "yes","no")
# 9.  **contact**: contact communication type (categorical: "unknown","telephone","cellular")
# 10.  **day**: last contact day of the month (numeric)
# 11.  **month**: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
# 12.  **duration**: last contact duration, in seconds (numeric)
# 13.  **campaign**: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 14.  **pdays**: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
# 15.  **previous**: number of contacts performed before this campaign and for this client (numeric)
# 16.  **poutcome**: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
# 17.  **y** - has the client subscribed a term deposit? (binary: "yes","no")

# %% [markdown]
# **Mentioned codes describes details about the dataset:**

# %%
data.describe()
# Out:
#                age      campaign  ...     euribor3m   nr.employed
# count  41188.00000  41188.000000  ...  41188.000000  41188.000000
# mean      40.02406      2.567593  ...      3.621291   5167.035911
# std       10.42125      2.770014  ...      1.734447     72.251528
# min       17.00000      1.000000  ...      0.634000   4963.600000
# 25%       32.00000      1.000000  ...      1.344000   5099.100000
# 50%       38.00000      2.000000  ...      4.857000   5191.000000
# 75%       47.00000      3.000000  ...      4.961000   5228.100000
# max       98.00000     56.000000  ...      5.045000   5228.100000
#
# [8 rows x 9 columns]

# %% [markdown]
# **To check null values in our dataset we executed following codes as follows:**

# %%
null=data.isnull().sum()
print(null)
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# Banking dataset does not have any missing values in any of the variables. We constructed multiple attempts to find out missing values, irrelevant data and unwanted variables.

# %% [markdown]
# **We felt that column default is unnecessary for us to we dropped that column from our dataset:**

# %%
data=data.drop(['default'], axis = 1)

# %% [markdown]
# **As you can see column default has been dropped from our dataset:**

# %%
data.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 19 columns]

# %% [markdown]
# **<h1><center> Electronic Design Automation [EDA]:</center></h1>**

# %% [markdown]
# **Below-mentioned bar chart represents the number of contacts performed during this campaign and for given marital status.**
#
# **We can clear see that number of contacts performed is greater for unknown marital status on the other hand single sort from the variable seems less contacted.**

# %%
plt.figure(figsize = (10,7))
sns.barplot(data.marital, data.campaign, color="skyblue", errcolor=".2", edgecolor=".2")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# **Histograms:**

# %%
# Plotting Histograms
fig, axes = plt.subplots(3, 2 , figsize=(14, 10))
sns.histplot(data['age'], ax=axes[0, 0])
sns.histplot(data['campaign'], ax=axes[1, 0])
sns.histplot(data['euribor3m'], ax=axes[0, 1])
sns.histplot(data['cons.price.idx'], ax=axes[2, 0])
sns.histplot(data['cons.conf.idx'], ax=axes[1, 1], bins=70)
fig.delaxes(axes[2,1])
fig.tight_layout()

# %% [markdown]
# **Count Plot for variables relevant to target variable**

# %%
 
cols = data.select_dtypes(include='category').columns.values
fig, axes = plt.subplots(3, 2, figsize=(15,8))
sns.countplot(data=data, x='marital', hue='marital', ax=axes[0,0])
sns.countplot(data=data, x='loan', hue='loan', ax=axes[0,1])
sns.countplot(data=data, x='housing', hue='housing', ax=axes[1,0])
sns.countplot(data=data, x='poutcome', hue='poutcome', ax=axes[1,1])
sns.countplot(data=data, x='contact', hue='contact', ax=axes[2,0])
sns.countplot(data=data, x='day_of_week', hue='day_of_week', ax=axes[2,1])

fig.tight_layout()

# %% [markdown]
# **As the future is all about digitalization can we have more effective campaigns via social media ?**

# %%
fig, axes = plt.subplots(figsize=(20,7))
cat_cols = data.select_dtypes(include='category').columns.values
sns.barplot(data=data, x='marital', y='campaign', hue='loan')
plt.title("Digitalization through Social Media", size=30)
plt.xlabel("Marital Status ", size=16)
plt.ylabel("Campaign", size=16)
fig.tight_layout()
plt.show()

# %% [markdown]
# *   We can predict that singles and the poeple who have deposited the loan  could attend campaign via social media. The reason being we assume singles having age 20-30. So, young generation obviously use Social Network.

# %% [markdown]
# **Is there a relation between job title /age /education /martial status & loan defaults?**

# %%
fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='marital', hue='housing')
fig.tight_layout()

fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='job', hue='housing')
fig.tight_layout()

fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='education', hue='housing')
fig.tight_layout()

fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='poutcome', hue='housing')
fig.tight_layout()

fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='month', hue='housing')
fig.tight_layout()

fig, axes = plt.subplots(figsize=(12,3))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='loan', hue='housing')
fig.tight_layout()

# %% [markdown]
# **From above analysis, we can see that variables reacted very well with the visualization**
#
# 1.   Initial plot represents the housing loan against marital status. We can observe that married people achieved highest number of count amongst others. It shows how these two variables are conncted to each other.
# 2. Each plot describes the feature of a variable based relevant to our target variable y.
# 3. There exists multiple number of univariate outliers in Age and Campaign data.

# %% [markdown]
# **How do different age groups respond to different methods of marketing for bank loans?**

# %%
fig, axes = plt.subplots(figsize=(8,7))
cat_cols = data.select_dtypes(include='category').columns.values
sns.barplot(data=data, x='poutcome', y='age')
fig.tight_layout()

# %%
fig, axes = plt.subplots(figsize=(20,7))
cat_cols = data.select_dtypes(include='category').columns.values
sns.countplot(data=data, x='age', hue='poutcome')
fig.tight_layout()

# %% [markdown]
# According to the dataset, to observe the behaviour between different age groups and methods for marketing bank loans we implemented count plot and bar plot for better visualization and understanding.
#
#
#
# 1.   Success : In our banking dataset the age above 40 achieved success in their banking terms.So, we can predict that age experience matters when you experencing banking elements.
# 2.   Failure: Majority of the people faced failure in banking. The factors which affected the poutcome might be the variables.
# 3.   Non-existent: We could have dropped this element from the variables poutcome but we wanted to see the count of non-existed people in banking dataset.

# %% [markdown]
# **Based on the relation between martial status, type of loan and type of marketing can we figure out optimal method of marketing(Telemarketing or Digital marketing - subscribed term deposit**

# %% [markdown]
# To figure the above-mentioned terminology we need to use three variables in a plot, either we can choose scatter plot or bar plot but in this case we chosen bar plot.
#
#
#
# *   Following we showed connection between target variable respective number of contacted persons.
# *   Based on the response of client subscribed term deposit, we showed  visulaization.

# %%
fig, axes = plt.subplots(figsize=(20,7))
cat_cols = data.select_dtypes(include='category').columns.values
sns.barplot(data=data, x='marital', y='campaign', hue='loan')
plt.title("Way of campaign marketing in loan based on marital status", size=30)
plt.xlabel("Marital Status ", size=16)
plt.ylabel("Campaign [No of Contact Performs]", size=16)
fig.tight_layout()
plt.show()

fig, axes = plt.subplots(figsize=(8,7))
cat_cols = data.select_dtypes(include='category').columns.values
sns.barplot(data=data, x='y', y='campaign')
plt.title("Variation of subscriptions based on the campaign", size=25)
plt.xlabel("Y [Term Deposit]", size=16)
plt.ylabel("Campaign [No of Contact Performs]", size=16)
fig.tight_layout()
plt.show()

# %% [markdown]
# **<h2><center>Visualization for better understanding of the variables</center></h2>**

# %% [markdown]
# **Violin Plot:**

# %%
fig, axes = plt.subplots(3, 2, figsize=(12,10))
sns.violinplot(data=data, x='housing', y='age', hue='housing', ax=axes[0,0])
sns.violinplot(data=data, x='housing', y='campaign', hue='housing', ax=axes[0,1])
sns.violinplot(data=data, x='housing', y='pdays', hue='housing', ax=axes[1,0])
sns.violinplot(data=data, x='housing', y='nr.employed', hue='housing', ax=axes[1,1])
sns.violinplot(data=data, x='housing', y='emp.var.rate', hue='housing', ax=axes[2,0])
fig.delaxes(axes[2,1])
fig.tight_layout()

# %% [markdown]
# **Box Plot:**

# %%
fig, axes = plt.subplots(1, 3, figsize=(12,5))
sns.boxplot(data=data, x='marital', y='age', hue='housing', ax=axes[0])
sns.boxplot(data=data, x='marital', y='campaign', hue='housing', ax=axes[1])
sns.boxplot(data=data, x='marital', y='nr.employed', hue='housing', ax=axes[2])
fig.tight_layout()

# %% [markdown]
# # Corelation Heatmap:

# %% [markdown]
# We believe heatmap is just an eyecatcher. Each square of an heatmap shows the correlation between the variables on x and y axis. Correlation of all variable  ranges from -1 to +1. We can see that heatmap started from age with +1 values shows positive trend and values closer to zero means there is no linear trend between the variables. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases . The diagonals are all 1/dark green because those squares are correlating each variable to itself (so it's a perfect correlation). For the rest the larger the number and darker the color the higher the correlation between the two variables. The plot is also symmetrical about the diagonal since the same two variable.

# %%
plt.figure(figsize=(15,15))
corr_matrix=data.corr()
sns.heatmap(corr_matrix,  square=True ,vmin=1,vmax=-1, cmap='Blues',annot=True,linewidth=1)
plt.title("Correlation heatmap")
plt.show()

# %% [markdown]
#
#
# *   From the above heatmap we can see that variable emp.var.rate and cons.price.idx represents 0.78 connectivity. As per variables relation colour of the box changes.
# *   Moreover the variable euribor3m and emp.var.rate also achieved 0.97. We can observe that the colour of that box is similar to the linear relation trend because the value is close to +1.
# * This is all about heatmap.

# %% [markdown]
# # Pairwise relations in dataset:

# %%
sns.pairplot(data, hue = 'housing')
plt.show()
